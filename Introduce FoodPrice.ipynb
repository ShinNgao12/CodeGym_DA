# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data/FoodPrice_in_Turkey.csv')
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
df.groupby('ProductName')[['Price']].mean().T
# Out:
# ProductName  Apples (red) - Retail  Apples - Retail  Bananas - Retail  \
# Price                     2.392193         3.885039          8.224784
#
# ProductName  Beans (white) - Retail  Bread (common) - Retail  \
# Price                       9.57283                 4.463293
#
# ProductName  Bread (pita) - Retail  Bulgur - Retail  Cabbage - Retail  \
# Price                     2.404545         3.516712          1.723395
#
# ProductName  Cauliflower - Retail  Cheese - Retail  ...  \
# Price                    3.274868        25.522875  ...
#
# ProductName  Tea (herbal) - Retail  Tea - Retail  Tomatoes (paste) - Retail  \
# Price                     5.434838     26.224393                   8.085128
#
# ProductName  Tomatoes - Retail  Transport (public) - Retail  \
# Price                 3.393658                     2.468031
#
# ProductName  Wage (non-qualified labour, non-agricultural) - Retail  \
# Price                                                40.548182
#
# ...

# %% [markdown]
# ### Một số đề xuất
# - Giá trung bình của từng mặt hàng qua từng năm
# - Với mỗi mặt hàng, tính được tháng mà mặt hàng đó có giá cao nhất trong năm
# - Địa điểm có nhiều mặt hàng đem bán nhất
